# %% [markdown]
# <a href="https://colab.research.google.com/github/Techusic/APS-Lab/blob/main/Lab_3_Growth_of_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Growth Of Function
# Time Complexity/Order of Growth defines the amount of time taken by any program with respect to the size of the input. Time Complexity specifies how the program would behave as the order of size of input is increased. So, Time Complexity is just a function of size of its input. We will go through some of basic and most common time complexities such as:
#
# - *Constant Time Complexity O(1) : constant running time*
# - *Linear Time Complexity O(n) : linear running time*
# - *Logarithmic Time Complexity O(log n) : logarithmic running time*
# - *Log-Linear Time Complexity O(n log n) : log-­linear running time*
# - *Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)*
# - *Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)*

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# ## Constant time Complexity:O(1)
# An algorithm is said to have constant time with order O (1) when it is not dependent on the input size n. Irrespective of the input size n, the runtime will always be the same. See example below

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random

# %%
# Prob_1: Demonstrating O(1) Constant Time Complexity for a simple addition function
def add_two_numbers(a, b):
    return a + b
n_values = list(range(1, 101))
time_values = []
for n in n_values:
    add_two_numbers(n, n + 1)
    time_values.append(1)
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Addition")
plt.show()

# %%
# Prob_2: Take another example and write the code that runs in fixed amount of time or has fixed number of steps of execution no matter what is the size of input has constant time complexity.
# similar to example-1, also plot the graph (eg. even_odd )
def half(number):
  a = number / 2
  return a
n_values = list(range(1, 50))
time_values = []
for n in n_values:
    half(n)
    time_values.append(1)
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(1) Constant Time Complexity for Division")
plt.show()

# %% [markdown]
# #Linear Time Complexity O(n) : linear running time
# - *An algorithm is said to have a linear time complexity when the running time increases linearly with the length of the input. When the function involves checking all the values in input data, with this order O(n).*

# %%
def linear_time_sum(numbers):
    total = 0
    for value in numbers:
        total += value
    return total

n_values = list(range(1, 101))
time_values = []

for n in n_values:
    data = list(range(n))
    linear_time_sum(data)
    time_values.append(n)

plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity")
plt.show()

# %%
# Prob_3: Take another example and write the code that runs in linear amount of time no matter what is the size of input..
# similar to example-2, also plot the graph (eg. even_oddcounts elements greater than zero)
def even_number_counter(numbers_list):
    count = 0
    for item in numbers_list:
      if item % 2 == 0:
        count+=1
    return count
n_values = list(range(1, 200))
time_values = []
for n in n_values:
    data = list(range(n))
    even_number_counter(data)
    time_values.append(n)
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time")
plt.title("O(n) Linear Time Complexity for counting even numbers in a list")
plt.show()

# %% [markdown]
# #Logarithmic Time Complexity O(log n) : logarithmic running time
# - *An algorithm is said to have a logarithmic time complexity when it reduces the size of the input data in each step. This indicates that the number of operations is not the same as the input size. The number of operations gets reduced as the input size increases. Algorithms are found in binary tree or binary search functions. This involves the search of a given value in an array by splitting the array into two and starting searching in one split. This ensures the operation is not done on every element of the data.*

# %%
# Prob_4: Take Suitable example and write function that runs in logarithmic time. plot graph as well similar to above example.
import math
def log_n_operations(n):
    count = 0
    while n > 1:
        n //= 2
        count += 1
    return count
n_values = list(range(1, 50001))
operation_counts = []
for n in n_values:
    operation_counts.append(log_n_operations(n))
plt.figure(figsize=(10, 6))
plt.plot(n_values, operation_counts)
plt.xlabel("Input size n")
plt.ylabel("Number of Operations")
plt.title("O(log n) Logarithmic Time Complexity (Operations Count)")
plt.show()
n_values = list(range(1, 50001))
operation_counts = []
for n in n_values:
    operation_counts.append(math.log(n))
plt.figure()
plt.plot(n_values, operation_counts)
plt.xlabel("Input size n")
plt.ylabel("Time (logarithmic scale)")
plt.title("O(log n) Logarithmic Time Complexity (Mathematical)")
plt.show()

# %% [markdown]
# #*Log-Linear Time Complexity O(n log n) : log-­linear running time*
#
#
# * When we call a Logarithmic Time Algorithm inside a loop, it would
# result into a Log-Linear Time Complexity program.

# %%
# Prob_5: Take Suitable example and write function that runs in log-linear time. plot the graph as well, similar to above example.
def merge_sort(arr):
    if len(arr) <= 1:
        return arr
    mid = len(arr) // 2
    left_half = arr[:mid]
    right_half = arr[mid:]
    left_half = merge_sort(left_half)
    right_half = merge_sort(right_half)
    return merge(left_half, right_half)
def merge(left, right):
    merged = []
    left_index, right_index = 0, 0
    while left_index < len(left) and right_index < len(right):
        if left[left_index] < right[right_index]:
            merged.append(left[left_index])
            left_index += 1
        else:
            merged.append(right[right_index])
            right_index += 1
    merged.extend(left[left_index:])
    merged.extend(right[right_index:])
    return merged
n_values = list(range(1, 1000))
time_values = []
for n in n_values:
    data = list(range(n))
    time_values.append(n * math.log(n + 1))
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (Theoretical n log n)")
plt.title("O(n log n) Log-Linear Time Complexity (Merge Sort)")
plt.show()

# %% [markdown]
# ### Polynomial Time Complexity O(n^c) : polynomial running time (c is a constant)
#
# * When the computation time increases as function of N raised to some power, N being the size of input. Such a code has Polynomial Time complexity.

# %%
# Prob_6: Take Suitable example and write function that runs in polynomial time. plot the graph as well, similar to above example.
def polynomial_time_function(n, c):
    return n ** c
n_values = list(range(1, 101))
time_values = []
for n in n_values:
    time_values.append(polynomial_time_function(n, 2))
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (Theoretical n^2)")
plt.title("O(n^c) Polynomial Time Complexity (e.g., O(n^2))")
plt.show()

# %% [markdown]
# #Exponential Time Complexity O(c^n) : exponential running time (c is a constant being raised to a power based on size of input)
#
# * When the computation time of a code increases as function of X^N, N being the size of input. Such a code has Polynomial Time Complexity.

# %%
# Prob_7: Take Suitable example and write function that runs in exponential time. plot the graph as well, similar to above example.
def exponential_time_function(n, c):
    return c ** n
n_values = list(range(1, 10))
time_values = []
for n in n_values:
    time_values.append(exponential_time_function(n, 2))
plt.figure()
plt.plot(n_values, time_values)
plt.xlabel("Input size n")
plt.ylabel("Time (Theoretical 2^n)")
plt.title("O(c^n) Exponential Time Complexity (e.g., O(2^n))")
plt.show()

# %% [markdown]
# #Importing required packages. plot graph similar to given figure
#
#
#
#
# ![1.png](data:image/png;base64,...)

# %%
#Prob_8 plot graph similar to above figure
import matplotlib.pyplot as plt
import numpy as np
def plot_graph():
    n_values = np.arange(1, 20)
    constant_time = np.ones_like(n_values)
    log_time = np.log(n_values)
    linear_time = n_values
    n_log_n_time = n_values * np.log(n_values)
    n_squared_time = n_values**2
    exponential_n_values = np.arange(1, 20)
    exponential_time = 2**exponential_n_values
    plt.figure(figsize=(12, 8))
    plt.plot(n_values, constant_time, label='O(1) - Constant', linestyle='-')
    plt.plot(n_values, log_time, label='O(log n) - Logarithmic', linestyle='-')
    plt.plot(n_values, linear_time, label='O(n) - Linear', linestyle='-')
    plt.plot(n_values, n_log_n_time, label='O(n log n) - Log-Linear', linestyle='-')
    plt.plot(n_values, n_squared_time, label='O(n^2) - Polynomial', linestyle='-')
    plt.plot(exponential_n_values, exponential_time, label='O(2^n) - Exponential', linestyle='-')
    plt.xlabel("Input Size (n)")
    plt.ylabel("Time/Operations")
    plt.title("Comparison of Time Complexities")
    plt.legend()
    plt.ylim(0, 1000)
    plt.show()
plot_graph()

# %%
# Write a function to perform quick sort and show that it has Logarithmic Time Complexity O(n log n)
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)
n_values = []
measured_time_values = []
theoretical_time_values = []
for n in range(10, 5000, 100):
    data = [random.randint(0, n) for _ in range(n)]
    start_time = time.time()
    quick_sort(data)
    end_time = time.time()
    n_values.append(n)
    measured_time_values.append(end_time - start_time)
    theoretical_time_values.append(n * math.log(n + 1))
plt.plot(n_values, theoretical_time_values)
plt.xlabel("Input Size (n)")
plt.ylabel("Time (seconds)")
plt.title("Quick Sort Time Complexity: O(n log n)")
plt.show()
